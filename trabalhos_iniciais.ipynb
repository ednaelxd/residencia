# %%
import pandas as pd
import numpy as np
import matplotlib as mth

# %% [markdown]
# # Importação

# %%
dollar=pd.read_excel("./datas/dolarBRL2011.2021.xlsx")
barril=pd.read_excel("./datas/petroleo.2011.2021.xlsx")
#gasolina=pd.read_excel("./datas/mensal-brasil-desde-jan2013.xlsx")

# %% [markdown]
# # Tratamento dos dados

# %% [markdown]
# ## Gasolina
# -

# %%
gas1=pd.read_csv("./datas/ca-2011-01.csv")
gas2=pd.read_csv("./datas/ca-2011-02.csv")
gas3=pd.read_csv("./datas/ca-2012-01.csv")
gas4=pd.read_csv("./datas/ca-2012-02.csv")

# %%
gas5=pd.read_csv("./datas/ca-2013-01.csv",decimal=',',sep=';')
gas6=pd.read_csv("./datas/ca-2013-02.csv",decimal=',',sep=';')
gas7=pd.read_csv("./datas/ca-2014-01.csv",decimal=',',sep=';')
gas8=pd.read_csv("./datas/ca-2014-02.csv",decimal=',',sep=';')
gas9=pd.read_csv("./datas/ca-2015-01.csv",decimal=',',sep=';')
gas10=pd.read_csv("./datas/ca-2015-02.csv",decimal=',',sep=';')
gas11=pd.read_csv("./datas/ca-2016-01.csv",decimal=',',sep=';')
gas12=pd.read_csv("./datas/ca-2016-02.csv",decimal=',',sep=';')
gas13=pd.read_csv("./datas/ca-2017-01.csv",decimal=',',sep=';')
gas14=pd.read_csv("./datas/ca-2017-02.csv",decimal=',',sep=';')
gas15=pd.read_csv("./datas/ca-2018-01.csv",decimal=',',sep=';')
gas16=pd.read_csv("./datas/ca-2018-02.csv",decimal=',',sep=';')
gas17=pd.read_csv("./datas/ca-2019-01.csv",decimal=',',sep=';')
gas18=pd.read_csv("./datas/ca-2019-02.csv",decimal=',',sep=';')
gas19=pd.read_csv("./datas/ca-2020-01.csv",decimal=',',sep=';')
gas20=pd.read_csv("./datas/ca-2020-02.csv",decimal=',',sep=';')

# %%
gas21=pd.read_csv("./datas/2021-01-gasolina-etanol.csv",decimal=',',sep=';')
gas22=pd.read_csv("./datas/2021-02-gasolina-etanol.csv",decimal=',',sep=';')
gas23=pd.read_csv("./datas/2021-03-gasolina-etanol.csv",decimal=',',sep=';')
gas24=pd.read_csv("./datas/2021-04-gasolina-etanol.csv",decimal=',',sep=';')
gas25=pd.read_csv("./datas/2021-05-gasolina-etanol.csv",decimal=',',sep=';')
gas26=pd.read_csv("./datas/2021-06-gasolina-etanol.csv",decimal=',',sep=';')
gas27=pd.read_csv("./datas/2021-07-gasolina-etanol.csv",decimal=',',sep=';')
gas28=pd.read_csv("./datas/2021-08-gasolina-etanol.csv",decimal=',',sep=';')
gas29=pd.read_csv("./datas/2021-09-gasolina-etanol.csv",decimal=',',sep=';')

# %%
gasgas=pd.concat([gas1,gas2,gas3,gas4,gas5,gas6,gas7,gas8,gas9,gas10,gas11,gas12,gas13,gas14,gas15,gas16])

# %%
gasgas=pd.concat([gasgas,gas17,gas18,gas19,gas20,gas21,gas22,gas23,gas24,gas25,gas26,gas27,gas28,gas29])

# %%
del(gas1,gas2,gas3,gas4,gas5,gas6,gas7,gas8,gas9,gas10,gas11,gas12,gas13,gas14,gas15,gas16,gas17,gas18,gas19,gas20,gas21,gas22,gas23,gas24,gas25,gas26,gas27,gas28,gas29)

# %%
gasgas.shape
# Out:
# (11138769, 19)

# %%
gasgas.set_index('Data da Coleta',inplace=True,drop=False)
gasgas.rename_axis('Período',inplace=True)
gasgas.head()
# Out:
# "gasgas.set_index('Data da Coleta',inplace=True,drop=False)\ngasgas.rename_axis('Período',inplace=True)\ngasgas.head()"

# %% [markdown]
# ## Fatiamento da base para apenas gasolina

# %%
df_gas=gasgas.loc[gasgas['Produto']=='GASOLINA',:]

# %%
del(gasgas)

# %%
df_gas.to_csv('df_gas.csv')

# %%
df_gas['Data da Coleta']=pd.to_datetime(df_gas['Data da Coleta'],format="%d/%m/%Y")
df_gas.sort_values('Data da Coleta',inplace=True)

# %%
df_gas.shape
# Out:
# (3581643, 19)

# %%
df_gas.set_index('Data da Coleta',drop=False,inplace=True)
df_gas.rename_axis('Período',inplace=True)
df_gas.head()
# Out:
#            Regiao - Sigla Estado - Sigla     Municipio  \
# Período
# 2011-01-03              S             PR   CAMPO LARGO
# 2011-01-03              S             PR  CAMPO MOURAO
# 2011-01-03              S             PR  CAMPO MOURAO
# 2011-01-03              S             PR  CAMPO MOURAO
# 2011-01-03              S             PR  CAMPO MOURAO
#
#                                          Revenda      CNPJ da Revenda  \
# Período
# 2011-01-03                       POSTO GRID LTDA   07.063.295/0001-94
# 2011-01-03  IDEAL COMÉRCIO DE COMBUSTÍVEIS LTDA.   08.681.346/0001-04
# 2011-01-03             AUTO POSTO GOTA AZUL LTDA   02.989.571/0001-26
# 2011-01-03              JACOMELI E JACOMELI LTDA   07.576.756/0001-22
# 2011-01-03            SAN MARINO AUTO POSTO LTDA   06.345.512/0001-76
#
#                                Nome da Rua Numero Rua Complemento  \
# Período
# 2011-01-03         RUA JOÃO BATISTA VALOES       1290         NaN
# ...

# %%
#df_gas.groupby(pd.Grouper(freq="M")).agg({'Valor de Venda':'mean'})

# %% [markdown]
# ## Retirada de colunas que não serão usadas

# %%
df_gas.isna().sum()
# Out:
# Regiao - Sigla        146151
# Estado - Sigla             0
# Municipio             146151
# Revenda                    0
# CNPJ da Revenda            0
# Nome da Rua                0
# Numero Rua            148238
# Complemento          2682576
# Bairro                 11970
# Cep                        0
# Produto                    0
# Data da Coleta             0
# Valor de Venda             0
# Valor de Compra      2074799
# Unidade de Medida          0
# Bandeira                   0
# Região - Sigla       3435492
# Município            3435492
# Número Rua           3435557
# dtype: int64

# %% [markdown]
# ## Remoção dos valores
# - Por número de Nan
# - Por relevância para o estudo

# %%
df_gas.drop(['Municipio','Complemento'],axis=1,inplace=True)
df_gas.drop(['Bandeira'],axis=1,inplace=True)

# %%
df_gas.drop(['Município','Cep','Número Rua','Numero Rua','Regiao - Sigla','Região - Sigla'],axis=1,inplace=True)

# %%
df_gas.head #pós remoção de colunas indesejadas
# Out:
#            Estado - Sigla                               Revenda  \
# Período
# 2011-01-03             PR                       POSTO GRID LTDA
# 2011-01-03             PR  IDEAL COMÉRCIO DE COMBUSTÍVEIS LTDA.
# 2011-01-03             PR             AUTO POSTO GOTA AZUL LTDA
# 2011-01-03             PR              JACOMELI E JACOMELI LTDA
# 2011-01-03             PR            SAN MARINO AUTO POSTO LTDA
#
#                 CNPJ da Revenda                     Nome da Rua  \
# Período
# 2011-01-03   07.063.295/0001-94         RUA JOÃO BATISTA VALOES
# 2011-01-03   08.681.346/0001-04          AVENIDA IRMÃOS PEREIRA
# 2011-01-03   02.989.571/0001-26                     RUA ARARUNA
# 2011-01-03   07.576.756/0001-22                 AVENIDA GOIOERÊ
# 2011-01-03   06.345.512/0001-76  AVENIDA CAPITAO INDIO BANDEIRA
#
#                      Bairro   Produto Data da Coleta  Valor de Venda  \
# Período
# 2011-01-03  SANTA TEREZINHA  GASOLINA     2011-01-03           2.550
# ...

# %% [markdown]
# # Análises da Base : Gasolina
# ## Informações acerca da coleta
# ## Contagens
# ## Plots da série

# %%
df_gas['Estado - Sigla'].hist(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
(df_gas['Estado - Sigla'].value_counts()/3581643).plot.pie(figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='Estado - Sigla'>

# %%
df_gas['ano']=df_gas['Data da Coleta'].dt.year
df_gas['mes']=df_gas['Data da Coleta'].dt.month
df_gas['dia']=df_gas['Data da Coleta'].dt.day

# %%
gp=df_gas[['Valor de Venda','Valor de Compra']].plot(marker='.',figsize=(20,5),subplots=True,linestyle='None')

# %%
resumo_gas=df_gas.groupby(['ano','mes']).agg({'Valor de Venda':['mean'],'Valor de Compra':['mean']})
resumo_gas.plot(marker='.',figsize=(15,5),linewidth=1,subplots=True,linestyle='None')
# Out:
# array([<AxesSubplot:xlabel='ano,mes'>, <AxesSubplot:xlabel='ano,mes'>],
#       dtype=object)

# %%
type(gp)
# Out:
# numpy.ndarray

# %%
resumo_gas=df_gas.groupby(['ano','mes']).agg({'Valor de Venda':['mean']})
resumo_gas.plot(figsize=(20,5),linewidth=1)
# Out:
# <AxesSubplot:xlabel='ano,mes'>

# %%
df_gas.head()
# Out:
#            Estado - Sigla                               Revenda  \
# Período
# 2011-01-03             PR                       POSTO GRID LTDA
# 2011-01-03             PR  IDEAL COMÉRCIO DE COMBUSTÍVEIS LTDA.
# 2011-01-03             PR             AUTO POSTO GOTA AZUL LTDA
# 2011-01-03             PR              JACOMELI E JACOMELI LTDA
# 2011-01-03             PR            SAN MARINO AUTO POSTO LTDA
#
#                 CNPJ da Revenda                     Nome da Rua  \
# Período
# 2011-01-03   07.063.295/0001-94         RUA JOÃO BATISTA VALOES
# 2011-01-03   08.681.346/0001-04          AVENIDA IRMÃOS PEREIRA
# 2011-01-03   02.989.571/0001-26                     RUA ARARUNA
# 2011-01-03   07.576.756/0001-22                 AVENIDA GOIOERÊ
# 2011-01-03   06.345.512/0001-76  AVENIDA CAPITAO INDIO BANDEIRA
#
#                      Bairro   Produto Data da Coleta  Valor de Venda  \
# Período
# 2011-01-03  SANTA TEREZINHA  GASOLINA     2011-01-03           2.550
# ...

# %%
colunas=['Valor de Venda','Valor de Compra']
gas_med_semanal = df_gas[colunas].resample('W').mean()
gas_med_diaria = df_gas['Valor de Venda'].resample('D').mean() #agora cada dia virou uma soh observacao
gas_med_mensal = df_gas['Valor de Venda'].resample('M').mean()

# %%
print(gas_med_semanal.shape)
print(gas_med_diaria.shape)
print(df_gas.shape)
print(gas_med_mensal.shape)
# Out:
# (561, 2)
# (3924,)
# (3581643, 13)
# (129,)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(13,5))
plt.plot(gas_med_diaria.loc['2011':'2015'],markersize=8,linestyle='-',linewidth=1,label='Diária')
plt.plot(gas_med_semanal.loc['2011':'2015','Valor de Venda'],marker='.',linestyle='-',linewidth=1,markersize=5,alpha=0.5,label='Semanal')

plt.legend()
plt.ylabel('Variação em R$')
plt.xlabel('Período do controle de preço')
# Out:
# Text(0.5, 0, 'Período do controle de preço')

# %%
plt.figure(figsize=(13,5))
plt.plot(gas_med_diaria.loc['2016':],markersize=8,linestyle='-',linewidth=1,label='Diária')
plt.plot(gas_med_semanal.loc['2016':,'Valor de Venda'],marker='.',linestyle='-',linewidth=1,markersize=5,alpha=0.5,label='Semanal')
plt.legend()
plt.ylabel('Variação em R$')
plt.xlabel('Período do PPI (incluindo pandemia)')
# Out:
# Text(0.5, 0, 'Período do PPI (incluindo pandemia)')

# %%
resumo_gas2=df_gas.groupby(['mes','ano']).agg({'Valor de Venda':['mean']})
resumo_gas2.plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='mes,ano'>

# %% [markdown]
# # Enriquecimento de dados [Mexer mais]
# - Adição de informações
# - Plotagens iniciais
# - Compreensão univariada

# %% [markdown]
# ## Dollar

# %%
#Criação de um valor médio para variação do dollar
dollar['V.Médio']=(dollar['Máxima']+dollar['Mínima'])/2
dollar.set_index('Data',inplace=True)
dollar.rename_axis('Período',inplace=True)

# %%
dollar.loc[:,'V.Médio'].plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Período'>

# %%
#Normalizando pelo valor máximo
dollar['VU$.Norm']=dollar['V.Médio']/dollar['V.Médio'].max()

# %%
dollar['pct_change']=dollar['V.Médio'].pct_change()*100

# %%
dollar.loc[:,'pct_change'].plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Período'>

# %%
dollar.loc['2013-01-1':,'VU$.Norm'].plot(figsize=(15,5))
# Out:
# C:\Users\ednae\anaconda3\envs\rsd\lib\site-packages\pandas\core\indexing.py:862: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   return getattr(section, self.name)[new_key]
# <AxesSubplot:xlabel='Período'>

# %% [markdown]
# ## Barril

# %%
barril['V.Médio']=(barril['Máxima']+barril['Mínima'])/2
barril.set_index('Data',inplace=True,drop=False)
barril.rename_axis('Período',inplace=True)

# %%
barril['pct_change']=barril['V.Médio'].pct_change()*100

# %%
barril.head()
# Out:
#                  Data  Último  Abertura  Máxima  Mínima    Vol.    Var%  \
# Período
# 2021-09-01 2021-09-01   78.25     71.68   79.94   70.42  97,97K  0.0721
# 2021-08-01 2021-08-01   72.99     75.39   75.39   64.60   5,51M -0.0438
# 2021-07-01 2021-07-01   76.33     74.69   77.84   67.44   5,85M  0.0160
# 2021-06-01 2021-06-01   75.13     69.39   76.60   69.29   5,06M  0.0838
# 2021-05-01 2021-05-01   69.32     66.70   70.24   64.57   5,09M  0.0308
#
#             V.Médio  pct_change
# Período
# 2021-09-01   75.180         NaN
# 2021-08-01   69.995   -6.896781
# 2021-07-01   72.640    3.778841
# 2021-06-01   72.945    0.419879
# 2021-05-01   67.405   -7.594763

# %%
barril['pct_change'].plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Período'>

# %%
barril['VBar.Norm']=barril['V.Médio']/barril['V.Médio'].max()
barril.loc[:,'VBar.Norm'].plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Período'>

# %% [markdown]
# ## Gasolina

# %%
df_gasolina['PMVGas.Norm']=df_gasolina['Preço Médio de Revenda']/df_gasolina['Preço Médio de Revenda'].max()
# Out:
# C:\Users\ednae\AppData\Local\Temp/ipykernel_9176/1631316045.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gasolina['PMVGas.Norm']=df_gasolina['Preço Médio de Revenda']/df_gasolina['Preço Médio de Revenda'].max()

# %%
df_gasolina['pct_change']=df_gasolina['Preço Médio de Revenda'].pct_change()*100
# Out:
# C:\Users\ednae\AppData\Local\Temp/ipykernel_9176/3135420196.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gasolina['pct_change']=df_gasolina['Preço Médio de Revenda'].pct_change()*100

# %%
df_gasolina['pct_change'].plot()
# Out:
# <AxesSubplot:xlabel='Período'>

# %%
df_gasolina['Preço Médio de Revenda'].plot()
# Out:
# <AxesSubplot:xlabel='Período'>

# %% [markdown]
# # Avaliações combinadas

# %%
df_gasolina['PMVGas.Norm'].plot(legend=True)
barril.loc['2013-01-1':,'VBar.Norm'].plot(legend=True)
dollar.loc['2013-01-1':,'VU$.Norm'].plot(legend=True)
# Out:
# C:\Users\ednae\anaconda3\envs\rsd\lib\site-packages\pandas\core\indexing.py:862: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   return getattr(section, self.name)[new_key]
# C:\Users\ednae\anaconda3\envs\rsd\lib\site-packages\pandas\core\indexing.py:862: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   return getattr(section, self.name)[new_key]
# <AxesSubplot:xlabel='Período'>

# %%
frames = pd.concat([df_gasolina['PMVGas.Norm'],barril.loc['2013-01-1':,'VBar.Norm'],dollar.loc['2013-01-1':,'VU$.Norm']],axis=1)
frames.corr()
# Out:
# C:\Users\ednae\anaconda3\envs\rsd\lib\site-packages\pandas\core\indexing.py:862: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   return getattr(section, self.name)[new_key]
#              PMVGas.Norm  VBar.Norm  VU$.Norm
# PMVGas.Norm     1.000000  -0.388830  0.832829
# VBar.Norm      -0.388830   1.000000 -0.639191
# VU$.Norm        0.832829  -0.639191  1.000000

# %%
frames.loc['2015-01-01':'2019-01-01'].corr()
#analisando apenas o período em questão
# Out:
#              PMVGas.Norm  VBar.Norm  VU$.Norm
# PMVGas.Norm     1.000000   0.655776  0.504830
# VBar.Norm       0.655776   1.000000  0.026837
# VU$.Norm        0.504830   0.026837  1.000000

# %%
frames.loc['2015-01-01':].corr()
# Out:
#              PMVGas.Norm  VBar.Norm  VU$.Norm
# PMVGas.Norm     1.000000   0.525400  0.694387
# VBar.Norm       0.525400   1.000000 -0.120171
# VU$.Norm        0.694387  -0.120171  1.000000

# %%
frames.loc['2015-01-01':'2016-01-01']
# Out:
#             PMVGas.Norm  VBar.Norm  VU$.Norm
# Período
# 2015-01-01     0.498848   0.415968  0.466182
# 2015-02-01     0.543106   0.458796  0.493206
# 2015-03-01     0.546726   0.461162  0.543423
# 2015-04-01     0.544258   0.484942  0.536484
# 2015-05-01     0.542777   0.524803  0.544430
# 2015-06-01     0.543106   0.510486  0.551245
# 2015-07-01     0.542284   0.461082  0.576309
# 2015-08-01     0.542119   0.387176  0.627224
# 2015-09-01     0.539158   0.398805  0.694568
# 2015-10-01     0.572557   0.402855  0.685889
# 2015-11-01     0.588351   0.377191  0.672391
# 2015-12-01     0.597730   0.325460  0.684883
# 2016-01-01     0.604804   0.265028  0.717946
